# %%
import team_analysis as ta

# %%
(analysis,summary) = ta.load_2024_data()

# %%
summary['frc_rank2'] = summary[
        ['rps','avg_coop_pts','avg_total_pts','avg_auto','avg_endgame']].apply(tuple,axis=1).rank(method='dense',ascending=True)
summary[ ['team.number','rps','avg_coop_pts','frc_rank2','avg_total_pts']].sort_values(by='frc_rank2',axis=0)
# Out:
#     team.number   rps  avg_coop_pts  frc_rank2  avg_total_pts
# 36         3876   0.0      0.000000        1.0       0.000000
# 37         3901   0.0      0.000000        2.0       0.000000
# 26         9571   0.0      0.000000        3.0       3.666667
# 25         3329   0.0      0.000000        4.0       4.400000
# 13            0   0.0      0.000000        5.0       8.000000
# 20         6167   0.0      0.142857        6.0       6.600000
# 23         3229   1.0      0.000000        7.0       5.000000
# 35          587   2.0      0.000000        8.0       0.000000
# 34         1293   2.0      0.000000        9.0       0.666667
# 31         3091   2.0      0.000000       10.0       2.500000
# 29         3976   2.0      0.000000       11.0       2.750000
# 24         3490   2.0      0.000000       12.0       4.800000
# 14         1539   2.0      0.000000       13.0       7.666667
# 7          9575   2.0      0.000000       14.0      12.000000
# ...
